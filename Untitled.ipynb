# %%
# Import the libraries we need
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Loading CSV file
df = pd.read_csv("weatherdataCMSE.csv")

# Keeping only the two columns we are interested in
data = df[['TMIN', 'TMAX']].dropna()

# Choosing the independent and dependent variables
# Here: AWND (wind) predicts PRCP (rain)
X = data[['TMIN']]   # independent variable
y = data['TMAX']     # dependent variable

# Create the model
model = LinearRegression()

# Train (fit) the model
model.fit(X, y)

# Print the results
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
print("R-squared:", model.score(X, y))

# Make a scatter plot with the regression line
plt.scatter(X, y, alpha=0.3, label="Data Points")
plt.plot(X, model.predict(X), label="Regression Line")
plt.xlabel("Minimum Temperature (TMIN)")
plt.ylabel("Maximum Temperature (TMAX)")
plt.title("Linear Regression: AWND vs WSF2")
plt.legend()
plt.show()
# Out:
# Slope: 1.0719442684153657
# Intercept: 13.532763956648154
# R-squared: 0.8956720763048303

# %%
# Import the libraries we need
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Loading CSV file
df = pd.read_csv("weatherdataCMSE.csv")

# Keeping only the two columns we are interested in
data = df[['WSF2', 'AWND']].dropna()

# Choosing the independent and dependent variables
# Here: AWND (wind) predicts PRCP (rain)
X = data[['AWND']]   # independent variable
y = data['WSF2']     # dependent variable

# Create the model
model = LinearRegression()

# Train (fit) the model
model.fit(X, y)

# Print the results
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
print("R-squared:", model.score(X, y))

# Make a scatter plot with the regression line
plt.scatter(X, y, alpha=0.3, label="Data Points")
plt.plot(X, model.predict(X), label="Regression Line")
plt.xlabel("Average Wind Speed (AWND)")
plt.ylabel("Fastest 2 Minute Wind Speed(WSF2)")
plt.title("Linear Regression: AWND vs WSF2")
plt.legend()
plt.show()
# Out:
# Slope: 1.3548268471013225
# Intercept: 6.840983745636912
# R-squared: 0.6811973221202765

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
df = pd.read_csv("weatherdataCMSE.csv")   # your file

# Select variables and drop missing rows
data = df[['TMAX', 'TMIN', 'AWND']].dropna()

# Define X and y
X = data[['TMIN', 'AWND']]   # independent variables
y = data['TMAX']             # dependent variable

# Add constant term for OLS intercept
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Display the full statistical report
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   TMAX   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.897
# Method:                 Least Squares   F-statistic:                 1.692e+04
# Date:                Mon, 17 Nov 2025   Prob (F-statistic):               0.00
# Time:                        14:06:53   Log-Likelihood:                -12759.
# No. Observations:                3879   AIC:                         2.552e+04
# Df Residuals:                    3876   BIC:                         2.554e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.7782      0.435     33.948      0.000      13.925      15.632
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
df = pd.read_csv("weatherdataCMSE.csv")   # your file

# Select variables and drop missing rows
data = df[['TMAX', 'TMIN', 'PGTM']].dropna()

# Define X and y
X = data[['TMIN', 'PGTM']]   # independent variables
y = data['TMAX']             # dependent variable

# Add constant term for OLS intercept
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Display the full statistical report
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   TMAX   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.899
# Method:                 Least Squares   F-statistic:                 1.734e+04
# Date:                Mon, 17 Nov 2025   Prob (F-statistic):               0.00
# Time:                        14:10:41   Log-Likelihood:                -12721.
# No. Observations:                3880   AIC:                         2.545e+04
# Df Residuals:                    3877   BIC:                         2.547e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.4753      0.343     33.434      0.000      10.802      12.148
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
df = pd.read_csv("weatherdataCMSE.csv")   # your file

# Select variables and drop missing rows
data = df[['TMAX', 'AWND', 'WT03']].dropna()

# Define X and y
X = data[['AWND', 'WT03']]   # independent variables
y = data['TMAX']             # dependent variable

# Add constant term for OLS intercept
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Display the full statistical report
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   TMAX   R-squared:                       0.491
# Model:                            OLS   Adj. R-squared:                  0.476
# Method:                 Least Squares   F-statistic:                     34.67
# Date:                Mon, 17 Nov 2025   Prob (F-statistic):           9.80e-07
# Time:                        14:26:21   Log-Likelihood:                -133.97
# No. Observations:                  38   AIC:                             271.9
# Df Residuals:                      36   BIC:                             275.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AWND          -2.6977      0.458     -5.888      0.000      -3.627      -1.769
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
df = pd.read_csv("weatherdataCMSE.csv")   # your file

# Select variables and drop missing rows
data = df[['PRCP', 'AWND', 'WT03']].dropna()

# Define X and y
X = data[['AWND', 'WT03']]   # independent variables
y = data['PRCP']             # dependent variable

# Add constant term for OLS intercept
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Display the full statistical report
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   PRCP   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     14.96
# Date:                Mon, 17 Nov 2025   Prob (F-statistic):           0.000442
# Time:                        14:25:44   Log-Likelihood:                -13.497
# No. Observations:                  38   AIC:                             30.99
# Df Residuals:                      36   BIC:                             34.27
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# AWND           0.0744      0.019      3.868      0.000       0.035       0.113
# ...

# %%
import pandas as pd
import statsmodels.api as sm

# Load the data
df = pd.read_csv("weatherdataCMSE.csv")   # your file

# Select variables and drop missing rows
data = df[['TMAX', 'TMIN', 'AWND']].dropna()

# Define X and y
X = data[['TMIN', 'TMAX']]   # independent variables
y = data['AWND']             # dependent variable

# Add constant term for OLS intercept
X = sm.add_constant(X)

# Fit the OLS model
model = sm.OLS(y, X).fit()

# Display the full statistical report
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   AWND   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.062
# Method:                 Least Squares   F-statistic:                     128.7
# Date:                Mon, 17 Nov 2025   Prob (F-statistic):           7.95e-55
# Time:                        14:27:44   Log-Likelihood:                -9885.2
# No. Observations:                3879   AIC:                         1.978e+04
# Df Residuals:                    3876   BIC:                         1.980e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         10.3568      0.168     61.690      0.000      10.028      10.686
# ...
